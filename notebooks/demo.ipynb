# %% [markdown]
# To execute a cell, hold `Ctrl` and press `Enter`.
#
# For more on Jupyter Notebooks, [click here](https://youtu.be/t7vfCWcywvQ?si=nDiQtJDiOQPZ_C0c).

# %%
# Install the analysis package

# %pip install -e ..

# %%
# Import the package and execute its data processing pipeline

import analysis
analysis.run()

# %%
# Start a new conversation with the OpenAI API regarding the output of analysis.run

chat = analysis.inspect.Chat()
chat.msg("What would be Jill's percentage of total spend if we did not attribute Amazon purchases to her?")

# %%
# Continue the conversation

chat.msg("What would Jack's be if we attributed them to him?")
